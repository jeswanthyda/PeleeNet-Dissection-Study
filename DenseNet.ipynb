# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, ZeroPadding2D, Concatenate, Dense, Dropout, Activation
from tensorflow.keras.layers import Convolution2D, AveragePooling2D, GlobalAveragePooling2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization
import tensorflow.keras.backend as K

# %%
def DenseNet(nb_dense_block=4, growth_rate=32, nb_filter=64, reduction=0.0, dropout_rate=0.0, weight_decay=1e-4, classes=1000, weights_path=None):
    '''Instantiate the DenseNet 121 architecture,
        # Arguments
            nb_dense_block: number of dense blocks to add to end
            growth_rate: number of filters to add per dense block
            nb_filter: initial number of filters
            reduction: reduction factor of transition blocks.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            classes: optional number of classes to classify images
            weights_path: path to pre-trained weights
        # Returns
            A Keras model instance.
    '''
    eps = 1.1e-5

    # compute compression factor
    compression = 1.0 - reduction

    # Handle Dimension Ordering for different backends
    global concat_axis
    
    concat_axis=-1
    img_input = Input(shape=(224, 224, 3), name='data')
    # From architecture for ImageNet (Table 1 in the paper)
    nb_filter = 24
    nb_layers = [6,12,24,16] # For DenseNet-121

    # Initial convolution
    x = ZeroPadding2D((3, 3), name='conv1_zeropadding')(img_input)
    x = Convolution2D(nb_filter, (3, 3), strides=(2, 2), name='conv1', use_bias=False)(x)
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv1_bn')(x)
    x = Activation('relu', name='relu1')(x)
    x = ZeroPadding2D((1, 1), name='pool1_zeropadding')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), name='pool1')(x)

    # Add dense blocks
    for block_idx in range(nb_dense_block - 1):
        stage = block_idx+2
        x, nb_filter = dense_block(x, stage, nb_layers[block_idx], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

        # Add transition_block
        x = transition_block(x, stage, nb_filter, compression=compression, dropout_rate=dropout_rate, weight_decay=weight_decay)
        nb_filter = int(nb_filter * compression)

    final_stage = stage + 1
    x, nb_filter = dense_block(x, final_stage, nb_layers[-1], nb_filter, growth_rate, dropout_rate=dropout_rate, weight_decay=weight_decay)

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name='conv'+str(final_stage)+'_blk_bn')(x)
    x = Activation('relu', name='relu'+str(final_stage)+'_blk')(x)
    x = GlobalAveragePooling2D(name='pool'+str(final_stage))(x)

    x = Dense(classes, name='fc6')(x)
    x = Activation('softmax', name='prob')(x)

    model = Model(img_input, x, name='densenet')

    return model

# %%
def conv_block(x, stage, branch, nb_filter, dropout_rate=None, weight_decay=1e-4):
    '''Apply BatchNorm, Relu, bottleneck 1x1 Conv2D, 3x3 Conv2D, and option dropout
        # Arguments
            x: input tensor 
            stage: index for dense block
            branch: layer index within each dense block
            nb_filter: number of filters
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''
    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_' + str(branch)
    relu_name_base = 'relu' + str(stage) + '_' + str(branch)

    # 1x1 Convolution (Bottleneck layer)
    inter_channel = nb_filter * 4  
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x1_bn')(x)
    x = Activation('relu', name=relu_name_base+'_x1')(x)
    x = Convolution2D(inter_channel, (1, 1), name=conv_name_base+'_x1', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    # 3x3 Convolution
    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_x2_bn')(x)
    x = Activation('relu', name=relu_name_base+'_x2')(x)
    x = ZeroPadding2D((1, 1), name=conv_name_base+'_x2_zeropadding')(x)
    x = Convolution2D(nb_filter, (3, 3), name=conv_name_base+'_x2', use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    return x

# %%
def transition_block(x, stage, nb_filter, compression=1.0, dropout_rate=None, weight_decay=1E-4):
    ''' Apply BatchNorm, 1x1 Convolution, averagePooling, optional compression, dropout 
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_filter: number of filters
            compression: calculated as 1 - reduction. Reduces the number of feature maps in the transition block.
            dropout_rate: dropout rate
            weight_decay: weight decay factor
    '''

    eps = 1.1e-5
    conv_name_base = 'conv' + str(stage) + '_blk'
    relu_name_base = 'relu' + str(stage) + '_blk'
    pool_name_base = 'pool' + str(stage) 

    x = BatchNormalization(epsilon=eps, axis=concat_axis, name=conv_name_base+'_bn')(x)
    x = Activation('relu', name=relu_name_base)(x)
    x = Convolution2D(int(nb_filter * compression), 1, 1, name=conv_name_base, use_bias=False)(x)

    if dropout_rate:
        x = Dropout(dropout_rate)(x)

    x = AveragePooling2D((2, 2), strides=(2, 2), name=pool_name_base)(x)

    return x

# %%
def dense_block(x, stage, nb_layers, nb_filter, growth_rate, dropout_rate=None, weight_decay=1e-4, grow_nb_filters=True):
    ''' Build a dense_block where the output of each conv_block is fed to subsequent ones
        # Arguments
            x: input tensor
            stage: index for dense block
            nb_layers: the number of layers of conv_block to append to the model.
            nb_filter: number of filters
            growth_rate: growth rate
            dropout_rate: dropout rate
            weight_decay: weight decay factor
            grow_nb_filters: flag to decide to allow number of filters to grow
    '''

    eps = 1.1e-5
    concat_feat = x

    for i in range(nb_layers):
        branch = i+1
        x = conv_block(concat_feat, stage, branch, growth_rate, dropout_rate, weight_decay)
        concat_feat = Concatenate()([concat_feat, x])
        
        if grow_nb_filters:
            nb_filter += growth_rate

    return concat_feat, nb_filter

# %%
model = DenseNet()
model.summary()
# Out:
# Model: "densenet"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_zeropadding (ZeroPadding2 (None, 230, 230, 3)  0           data[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 114, 114, 24) 648         conv1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 114, 114, 24) 96          conv1[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 114, 114, 24) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_zeropadding (ZeroPadding2 (None, 116, 116, 24) 0           relu1[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 57, 57, 24)   0           pool1_zeropadding[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1_bn (BatchNormalizati (None, 57, 57, 24)   96          pool1[0][0]
# __________________________________________________________________________________________________
# relu2_1_x1 (Activation)         (None, 57, 57, 24)   0           conv2_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_x1 (Conv2D)             (None, 57, 57, 128)  3072        relu2_1_x1[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_1_x1[0][0]
# __________________________________________________________________________________________________
# relu2_1_x2 (Activation)         (None, 57, 57, 128)  0           conv2_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_1_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 57, 57, 56)   0           pool1[0][0]
#                                                                  conv2_1_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1_bn (BatchNormalizati (None, 57, 57, 56)   224         concatenate_58[0][0]
# __________________________________________________________________________________________________
# relu2_2_x1 (Activation)         (None, 57, 57, 56)   0           conv2_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_x1 (Conv2D)             (None, 57, 57, 128)  7168        relu2_2_x1[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_2_x1[0][0]
# __________________________________________________________________________________________________
# relu2_2_x2 (Activation)         (None, 57, 57, 128)  0           conv2_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_2_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 57, 57, 88)   0           concatenate_58[0][0]
#                                                                  conv2_2_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1_bn (BatchNormalizati (None, 57, 57, 88)   352         concatenate_59[0][0]
# __________________________________________________________________________________________________
# relu2_3_x1 (Activation)         (None, 57, 57, 88)   0           conv2_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_x1 (Conv2D)             (None, 57, 57, 128)  11264       relu2_3_x1[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_3_x1[0][0]
# __________________________________________________________________________________________________
# relu2_3_x2 (Activation)         (None, 57, 57, 128)  0           conv2_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_3_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_60 (Concatenate)    (None, 57, 57, 120)  0           concatenate_59[0][0]
#                                                                  conv2_3_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1_bn (BatchNormalizati (None, 57, 57, 120)  480         concatenate_60[0][0]
# __________________________________________________________________________________________________
# relu2_4_x1 (Activation)         (None, 57, 57, 120)  0           conv2_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_4_x1 (Conv2D)             (None, 57, 57, 128)  15360       relu2_4_x1[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_4_x1[0][0]
# __________________________________________________________________________________________________
# relu2_4_x2 (Activation)         (None, 57, 57, 128)  0           conv2_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_4_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_61 (Concatenate)    (None, 57, 57, 152)  0           concatenate_60[0][0]
#                                                                  conv2_4_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1_bn (BatchNormalizati (None, 57, 57, 152)  608         concatenate_61[0][0]
# __________________________________________________________________________________________________
# relu2_5_x1 (Activation)         (None, 57, 57, 152)  0           conv2_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_5_x1 (Conv2D)             (None, 57, 57, 128)  19456       relu2_5_x1[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_5_x1[0][0]
# __________________________________________________________________________________________________
# relu2_5_x2 (Activation)         (None, 57, 57, 128)  0           conv2_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_5_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_62 (Concatenate)    (None, 57, 57, 184)  0           concatenate_61[0][0]
#                                                                  conv2_5_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1_bn (BatchNormalizati (None, 57, 57, 184)  736         concatenate_62[0][0]
# __________________________________________________________________________________________________
# relu2_6_x1 (Activation)         (None, 57, 57, 184)  0           conv2_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_6_x1 (Conv2D)             (None, 57, 57, 128)  23552       relu2_6_x1[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_bn (BatchNormalizati (None, 57, 57, 128)  512         conv2_6_x1[0][0]
# __________________________________________________________________________________________________
# relu2_6_x2 (Activation)         (None, 57, 57, 128)  0           conv2_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2_zeropadding (ZeroPad (None, 59, 59, 128)  0           relu2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_6_x2 (Conv2D)             (None, 57, 57, 32)   36864       conv2_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_63 (Concatenate)    (None, 57, 57, 216)  0           concatenate_62[0][0]
#                                                                  conv2_6_x2[0][0]
# __________________________________________________________________________________________________
# conv2_blk_bn (BatchNormalizatio (None, 57, 57, 216)  864         concatenate_63[0][0]
# __________________________________________________________________________________________________
# relu2_blk (Activation)          (None, 57, 57, 216)  0           conv2_blk_bn[0][0]
# __________________________________________________________________________________________________
# conv2_blk (Conv2D)              (None, 57, 57, 216)  46656       relu2_blk[0][0]
# __________________________________________________________________________________________________
# pool2 (AveragePooling2D)        (None, 28, 28, 216)  0           conv2_blk[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1_bn (BatchNormalizati (None, 28, 28, 216)  864         pool2[0][0]
# __________________________________________________________________________________________________
# relu3_1_x1 (Activation)         (None, 28, 28, 216)  0           conv3_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_x1 (Conv2D)             (None, 28, 28, 128)  27648       relu3_1_x1[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_1_x1[0][0]
# __________________________________________________________________________________________________
# relu3_1_x2 (Activation)         (None, 28, 28, 128)  0           conv3_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_1_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 28, 28, 248)  0           pool2[0][0]
#                                                                  conv3_1_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1_bn (BatchNormalizati (None, 28, 28, 248)  992         concatenate_64[0][0]
# __________________________________________________________________________________________________
# relu3_2_x1 (Activation)         (None, 28, 28, 248)  0           conv3_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_x1 (Conv2D)             (None, 28, 28, 128)  31744       relu3_2_x1[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_2_x1[0][0]
# __________________________________________________________________________________________________
# relu3_2_x2 (Activation)         (None, 28, 28, 128)  0           conv3_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_2_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 28, 28, 280)  0           concatenate_64[0][0]
#                                                                  conv3_2_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1_bn (BatchNormalizati (None, 28, 28, 280)  1120        concatenate_65[0][0]
# __________________________________________________________________________________________________
# relu3_3_x1 (Activation)         (None, 28, 28, 280)  0           conv3_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_x1 (Conv2D)             (None, 28, 28, 128)  35840       relu3_3_x1[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_3_x1[0][0]
# __________________________________________________________________________________________________
# relu3_3_x2 (Activation)         (None, 28, 28, 128)  0           conv3_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_3_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_66 (Concatenate)    (None, 28, 28, 312)  0           concatenate_65[0][0]
#                                                                  conv3_3_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1_bn (BatchNormalizati (None, 28, 28, 312)  1248        concatenate_66[0][0]
# __________________________________________________________________________________________________
# relu3_4_x1 (Activation)         (None, 28, 28, 312)  0           conv3_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_x1 (Conv2D)             (None, 28, 28, 128)  39936       relu3_4_x1[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_4_x1[0][0]
# __________________________________________________________________________________________________
# relu3_4_x2 (Activation)         (None, 28, 28, 128)  0           conv3_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_4_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_67 (Concatenate)    (None, 28, 28, 344)  0           concatenate_66[0][0]
#                                                                  conv3_4_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1_bn (BatchNormalizati (None, 28, 28, 344)  1376        concatenate_67[0][0]
# __________________________________________________________________________________________________
# relu3_5_x1 (Activation)         (None, 28, 28, 344)  0           conv3_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_5_x1 (Conv2D)             (None, 28, 28, 128)  44032       relu3_5_x1[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_5_x1[0][0]
# __________________________________________________________________________________________________
# relu3_5_x2 (Activation)         (None, 28, 28, 128)  0           conv3_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_5_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_68 (Concatenate)    (None, 28, 28, 376)  0           concatenate_67[0][0]
#                                                                  conv3_5_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1_bn (BatchNormalizati (None, 28, 28, 376)  1504        concatenate_68[0][0]
# __________________________________________________________________________________________________
# relu3_6_x1 (Activation)         (None, 28, 28, 376)  0           conv3_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_6_x1 (Conv2D)             (None, 28, 28, 128)  48128       relu3_6_x1[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_6_x1[0][0]
# __________________________________________________________________________________________________
# relu3_6_x2 (Activation)         (None, 28, 28, 128)  0           conv3_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_6_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_69 (Concatenate)    (None, 28, 28, 408)  0           concatenate_68[0][0]
#                                                                  conv3_6_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1_bn (BatchNormalizati (None, 28, 28, 408)  1632        concatenate_69[0][0]
# __________________________________________________________________________________________________
# relu3_7_x1 (Activation)         (None, 28, 28, 408)  0           conv3_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_7_x1 (Conv2D)             (None, 28, 28, 128)  52224       relu3_7_x1[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_7_x1[0][0]
# __________________________________________________________________________________________________
# relu3_7_x2 (Activation)         (None, 28, 28, 128)  0           conv3_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_7_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_7_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_70 (Concatenate)    (None, 28, 28, 440)  0           concatenate_69[0][0]
#                                                                  conv3_7_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1_bn (BatchNormalizati (None, 28, 28, 440)  1760        concatenate_70[0][0]
# __________________________________________________________________________________________________
# relu3_8_x1 (Activation)         (None, 28, 28, 440)  0           conv3_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_8_x1 (Conv2D)             (None, 28, 28, 128)  56320       relu3_8_x1[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_8_x1[0][0]
# __________________________________________________________________________________________________
# relu3_8_x2 (Activation)         (None, 28, 28, 128)  0           conv3_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_8_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_71 (Concatenate)    (None, 28, 28, 472)  0           concatenate_70[0][0]
#                                                                  conv3_8_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1_bn (BatchNormalizati (None, 28, 28, 472)  1888        concatenate_71[0][0]
# __________________________________________________________________________________________________
# relu3_9_x1 (Activation)         (None, 28, 28, 472)  0           conv3_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_9_x1 (Conv2D)             (None, 28, 28, 128)  60416       relu3_9_x1[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_bn (BatchNormalizati (None, 28, 28, 128)  512         conv3_9_x1[0][0]
# __________________________________________________________________________________________________
# relu3_9_x2 (Activation)         (None, 28, 28, 128)  0           conv3_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2_zeropadding (ZeroPad (None, 30, 30, 128)  0           relu3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_9_x2 (Conv2D)             (None, 28, 28, 32)   36864       conv3_9_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_72 (Concatenate)    (None, 28, 28, 504)  0           concatenate_71[0][0]
#                                                                  conv3_9_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1_bn (BatchNormalizat (None, 28, 28, 504)  2016        concatenate_72[0][0]
# __________________________________________________________________________________________________
# relu3_10_x1 (Activation)        (None, 28, 28, 504)  0           conv3_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_10_x1 (Conv2D)            (None, 28, 28, 128)  64512       relu3_10_x1[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_10_x1[0][0]
# __________________________________________________________________________________________________
# relu3_10_x2 (Activation)        (None, 28, 28, 128)  0           conv3_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2_zeropadding (ZeroPa (None, 30, 30, 128)  0           relu3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_10_x2 (Conv2D)            (None, 28, 28, 32)   36864       conv3_10_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_73 (Concatenate)    (None, 28, 28, 536)  0           concatenate_72[0][0]
#                                                                  conv3_10_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1_bn (BatchNormalizat (None, 28, 28, 536)  2144        concatenate_73[0][0]
# __________________________________________________________________________________________________
# relu3_11_x1 (Activation)        (None, 28, 28, 536)  0           conv3_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_11_x1 (Conv2D)            (None, 28, 28, 128)  68608       relu3_11_x1[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_11_x1[0][0]
# __________________________________________________________________________________________________
# relu3_11_x2 (Activation)        (None, 28, 28, 128)  0           conv3_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2_zeropadding (ZeroPa (None, 30, 30, 128)  0           relu3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_11_x2 (Conv2D)            (None, 28, 28, 32)   36864       conv3_11_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_74 (Concatenate)    (None, 28, 28, 568)  0           concatenate_73[0][0]
#                                                                  conv3_11_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1_bn (BatchNormalizat (None, 28, 28, 568)  2272        concatenate_74[0][0]
# __________________________________________________________________________________________________
# relu3_12_x1 (Activation)        (None, 28, 28, 568)  0           conv3_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_12_x1 (Conv2D)            (None, 28, 28, 128)  72704       relu3_12_x1[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_bn (BatchNormalizat (None, 28, 28, 128)  512         conv3_12_x1[0][0]
# __________________________________________________________________________________________________
# relu3_12_x2 (Activation)        (None, 28, 28, 128)  0           conv3_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2_zeropadding (ZeroPa (None, 30, 30, 128)  0           relu3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_12_x2 (Conv2D)            (None, 28, 28, 32)   36864       conv3_12_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_75 (Concatenate)    (None, 28, 28, 600)  0           concatenate_74[0][0]
#                                                                  conv3_12_x2[0][0]
# __________________________________________________________________________________________________
# conv3_blk_bn (BatchNormalizatio (None, 28, 28, 600)  2400        concatenate_75[0][0]
# __________________________________________________________________________________________________
# relu3_blk (Activation)          (None, 28, 28, 600)  0           conv3_blk_bn[0][0]
# __________________________________________________________________________________________________
# conv3_blk (Conv2D)              (None, 28, 28, 600)  360000      relu3_blk[0][0]
# __________________________________________________________________________________________________
# pool3 (AveragePooling2D)        (None, 14, 14, 600)  0           conv3_blk[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1_bn (BatchNormalizati (None, 14, 14, 600)  2400        pool3[0][0]
# __________________________________________________________________________________________________
# relu4_1_x1 (Activation)         (None, 14, 14, 600)  0           conv4_1_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_x1 (Conv2D)             (None, 14, 14, 128)  76800       relu4_1_x1[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_1_x1[0][0]
# __________________________________________________________________________________________________
# relu4_1_x2 (Activation)         (None, 14, 14, 128)  0           conv4_1_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_1_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_1_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_76 (Concatenate)    (None, 14, 14, 632)  0           pool3[0][0]
#                                                                  conv4_1_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1_bn (BatchNormalizati (None, 14, 14, 632)  2528        concatenate_76[0][0]
# __________________________________________________________________________________________________
# relu4_2_x1 (Activation)         (None, 14, 14, 632)  0           conv4_2_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_x1 (Conv2D)             (None, 14, 14, 128)  80896       relu4_2_x1[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_2_x1[0][0]
# __________________________________________________________________________________________________
# relu4_2_x2 (Activation)         (None, 14, 14, 128)  0           conv4_2_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_2_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_2_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_77 (Concatenate)    (None, 14, 14, 664)  0           concatenate_76[0][0]
#                                                                  conv4_2_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1_bn (BatchNormalizati (None, 14, 14, 664)  2656        concatenate_77[0][0]
# __________________________________________________________________________________________________
# relu4_3_x1 (Activation)         (None, 14, 14, 664)  0           conv4_3_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_x1 (Conv2D)             (None, 14, 14, 128)  84992       relu4_3_x1[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_3_x1[0][0]
# __________________________________________________________________________________________________
# relu4_3_x2 (Activation)         (None, 14, 14, 128)  0           conv4_3_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_3_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_3_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_78 (Concatenate)    (None, 14, 14, 696)  0           concatenate_77[0][0]
#                                                                  conv4_3_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1_bn (BatchNormalizati (None, 14, 14, 696)  2784        concatenate_78[0][0]
# __________________________________________________________________________________________________
# relu4_4_x1 (Activation)         (None, 14, 14, 696)  0           conv4_4_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_x1 (Conv2D)             (None, 14, 14, 128)  89088       relu4_4_x1[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_4_x1[0][0]
# __________________________________________________________________________________________________
# relu4_4_x2 (Activation)         (None, 14, 14, 128)  0           conv4_4_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_4_x2[0][0]
# __________________________________________________________________________________________________
# conv4_4_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_4_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 14, 14, 728)  0           concatenate_78[0][0]
#                                                                  conv4_4_x2[0][0]
# __________________________________________________________________________________________________
# conv4_5_x1_bn (BatchNormalizati (None, 14, 14, 728)  2912        concatenate_79[0][0]
# __________________________________________________________________________________________________
# relu4_5_x1 (Activation)         (None, 14, 14, 728)  0           conv4_5_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_x1 (Conv2D)             (None, 14, 14, 128)  93184       relu4_5_x1[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_5_x1[0][0]
# __________________________________________________________________________________________________
# relu4_5_x2 (Activation)         (None, 14, 14, 128)  0           conv4_5_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_5_x2[0][0]
# __________________________________________________________________________________________________
# conv4_5_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_5_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_80 (Concatenate)    (None, 14, 14, 760)  0           concatenate_79[0][0]
#                                                                  conv4_5_x2[0][0]
# __________________________________________________________________________________________________
# conv4_6_x1_bn (BatchNormalizati (None, 14, 14, 760)  3040        concatenate_80[0][0]
# __________________________________________________________________________________________________
# relu4_6_x1 (Activation)         (None, 14, 14, 760)  0           conv4_6_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_x1 (Conv2D)             (None, 14, 14, 128)  97280       relu4_6_x1[0][0]
# __________________________________________________________________________________________________
# conv4_6_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_6_x1[0][0]
# __________________________________________________________________________________________________
# relu4_6_x2 (Activation)         (None, 14, 14, 128)  0           conv4_6_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_6_x2[0][0]
# __________________________________________________________________________________________________
# conv4_6_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_6_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_81 (Concatenate)    (None, 14, 14, 792)  0           concatenate_80[0][0]
#                                                                  conv4_6_x2[0][0]
# __________________________________________________________________________________________________
# conv4_7_x1_bn (BatchNormalizati (None, 14, 14, 792)  3168        concatenate_81[0][0]
# __________________________________________________________________________________________________
# relu4_7_x1 (Activation)         (None, 14, 14, 792)  0           conv4_7_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_7_x1 (Conv2D)             (None, 14, 14, 128)  101376      relu4_7_x1[0][0]
# __________________________________________________________________________________________________
# conv4_7_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_7_x1[0][0]
# __________________________________________________________________________________________________
# relu4_7_x2 (Activation)         (None, 14, 14, 128)  0           conv4_7_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_7_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_7_x2[0][0]
# __________________________________________________________________________________________________
# conv4_7_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_7_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_82 (Concatenate)    (None, 14, 14, 824)  0           concatenate_81[0][0]
#                                                                  conv4_7_x2[0][0]
# __________________________________________________________________________________________________
# conv4_8_x1_bn (BatchNormalizati (None, 14, 14, 824)  3296        concatenate_82[0][0]
# __________________________________________________________________________________________________
# relu4_8_x1 (Activation)         (None, 14, 14, 824)  0           conv4_8_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_8_x1 (Conv2D)             (None, 14, 14, 128)  105472      relu4_8_x1[0][0]
# __________________________________________________________________________________________________
# conv4_8_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_8_x1[0][0]
# __________________________________________________________________________________________________
# relu4_8_x2 (Activation)         (None, 14, 14, 128)  0           conv4_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_8_x2_zeropadding (ZeroPad (None, 16, 16, 128)  0           relu4_8_x2[0][0]
# __________________________________________________________________________________________________
# conv4_8_x2 (Conv2D)             (None, 14, 14, 32)   36864       conv4_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_83 (Concatenate)    (None, 14, 14, 856)  0           concatenate_82[0][0]
#                                                                  conv4_8_x2[0][0]
# __________________________________________________________________________________________________
# conv4_9_x1_bn (BatchNormalizati (None, 14, 14, 856)  3424        concatenate_83[0][0]
# __________________________________________________________________________________________________
# relu4_9_x1 (Activation)         (None, 14, 14, 856)  0           conv4_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_9_x1 (Conv2D)             (None, 14, 14, 128)  109568      relu4_9_x1[0][0]
# __________________________________________________________________________________________________
# conv4_9_x2_bn (BatchNormalizati (None, 14, 14, 128)  512         conv4_9_x1[0][0]
# __________________________________________________________________________________________________
# relu4_9_x2 (Activation)         (None, 14, 14, 128)  0           conv4_9_x2_bn[0][0]
# ...
# conv5_8_x1 (Conv2D)             (None, 7, 7, 128)    203776      relu5_8_x1[0][0]
# __________________________________________________________________________________________________
# conv5_8_x2_bn (BatchNormalizati (None, 7, 7, 128)    512         conv5_8_x1[0][0]
# __________________________________________________________________________________________________
# relu5_8_x2 (Activation)         (None, 7, 7, 128)    0           conv5_8_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_8_x2_zeropadding (ZeroPad (None, 9, 9, 128)    0           relu5_8_x2[0][0]
# __________________________________________________________________________________________________
# conv5_8_x2 (Conv2D)             (None, 7, 7, 32)     36864       conv5_8_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_107 (Concatenate)   (None, 7, 7, 1624)   0           concatenate_106[0][0]
#                                                                  conv5_8_x2[0][0]
# __________________________________________________________________________________________________
# conv5_9_x1_bn (BatchNormalizati (None, 7, 7, 1624)   6496        concatenate_107[0][0]
# __________________________________________________________________________________________________
# relu5_9_x1 (Activation)         (None, 7, 7, 1624)   0           conv5_9_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_9_x1 (Conv2D)             (None, 7, 7, 128)    207872      relu5_9_x1[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2_bn (BatchNormalizati (None, 7, 7, 128)    512         conv5_9_x1[0][0]
# __________________________________________________________________________________________________
# relu5_9_x2 (Activation)         (None, 7, 7, 128)    0           conv5_9_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2_zeropadding (ZeroPad (None, 9, 9, 128)    0           relu5_9_x2[0][0]
# __________________________________________________________________________________________________
# conv5_9_x2 (Conv2D)             (None, 7, 7, 32)     36864       conv5_9_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_108 (Concatenate)   (None, 7, 7, 1656)   0           concatenate_107[0][0]
#                                                                  conv5_9_x2[0][0]
# __________________________________________________________________________________________________
# conv5_10_x1_bn (BatchNormalizat (None, 7, 7, 1656)   6624        concatenate_108[0][0]
# __________________________________________________________________________________________________
# relu5_10_x1 (Activation)        (None, 7, 7, 1656)   0           conv5_10_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_10_x1 (Conv2D)            (None, 7, 7, 128)    211968      relu5_10_x1[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_10_x1[0][0]
# __________________________________________________________________________________________________
# relu5_10_x2 (Activation)        (None, 7, 7, 128)    0           conv5_10_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_10_x2[0][0]
# __________________________________________________________________________________________________
# conv5_10_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_10_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_109 (Concatenate)   (None, 7, 7, 1688)   0           concatenate_108[0][0]
#                                                                  conv5_10_x2[0][0]
# __________________________________________________________________________________________________
# conv5_11_x1_bn (BatchNormalizat (None, 7, 7, 1688)   6752        concatenate_109[0][0]
# __________________________________________________________________________________________________
# relu5_11_x1 (Activation)        (None, 7, 7, 1688)   0           conv5_11_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_11_x1 (Conv2D)            (None, 7, 7, 128)    216064      relu5_11_x1[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_11_x1[0][0]
# __________________________________________________________________________________________________
# relu5_11_x2 (Activation)        (None, 7, 7, 128)    0           conv5_11_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_11_x2[0][0]
# __________________________________________________________________________________________________
# conv5_11_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_11_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_110 (Concatenate)   (None, 7, 7, 1720)   0           concatenate_109[0][0]
#                                                                  conv5_11_x2[0][0]
# __________________________________________________________________________________________________
# conv5_12_x1_bn (BatchNormalizat (None, 7, 7, 1720)   6880        concatenate_110[0][0]
# __________________________________________________________________________________________________
# relu5_12_x1 (Activation)        (None, 7, 7, 1720)   0           conv5_12_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_12_x1 (Conv2D)            (None, 7, 7, 128)    220160      relu5_12_x1[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_12_x1[0][0]
# __________________________________________________________________________________________________
# relu5_12_x2 (Activation)        (None, 7, 7, 128)    0           conv5_12_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_12_x2[0][0]
# __________________________________________________________________________________________________
# conv5_12_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_12_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_111 (Concatenate)   (None, 7, 7, 1752)   0           concatenate_110[0][0]
#                                                                  conv5_12_x2[0][0]
# __________________________________________________________________________________________________
# conv5_13_x1_bn (BatchNormalizat (None, 7, 7, 1752)   7008        concatenate_111[0][0]
# __________________________________________________________________________________________________
# relu5_13_x1 (Activation)        (None, 7, 7, 1752)   0           conv5_13_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_13_x1 (Conv2D)            (None, 7, 7, 128)    224256      relu5_13_x1[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_13_x1[0][0]
# __________________________________________________________________________________________________
# relu5_13_x2 (Activation)        (None, 7, 7, 128)    0           conv5_13_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_13_x2[0][0]
# __________________________________________________________________________________________________
# conv5_13_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_13_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_112 (Concatenate)   (None, 7, 7, 1784)   0           concatenate_111[0][0]
#                                                                  conv5_13_x2[0][0]
# __________________________________________________________________________________________________
# conv5_14_x1_bn (BatchNormalizat (None, 7, 7, 1784)   7136        concatenate_112[0][0]
# __________________________________________________________________________________________________
# relu5_14_x1 (Activation)        (None, 7, 7, 1784)   0           conv5_14_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_14_x1 (Conv2D)            (None, 7, 7, 128)    228352      relu5_14_x1[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_14_x1[0][0]
# __________________________________________________________________________________________________
# relu5_14_x2 (Activation)        (None, 7, 7, 128)    0           conv5_14_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_14_x2[0][0]
# __________________________________________________________________________________________________
# conv5_14_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_14_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_113 (Concatenate)   (None, 7, 7, 1816)   0           concatenate_112[0][0]
#                                                                  conv5_14_x2[0][0]
# __________________________________________________________________________________________________
# conv5_15_x1_bn (BatchNormalizat (None, 7, 7, 1816)   7264        concatenate_113[0][0]
# __________________________________________________________________________________________________
# relu5_15_x1 (Activation)        (None, 7, 7, 1816)   0           conv5_15_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_15_x1 (Conv2D)            (None, 7, 7, 128)    232448      relu5_15_x1[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_15_x1[0][0]
# __________________________________________________________________________________________________
# relu5_15_x2 (Activation)        (None, 7, 7, 128)    0           conv5_15_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_15_x2[0][0]
# __________________________________________________________________________________________________
# conv5_15_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_15_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_114 (Concatenate)   (None, 7, 7, 1848)   0           concatenate_113[0][0]
#                                                                  conv5_15_x2[0][0]
# __________________________________________________________________________________________________
# conv5_16_x1_bn (BatchNormalizat (None, 7, 7, 1848)   7392        concatenate_114[0][0]
# __________________________________________________________________________________________________
# relu5_16_x1 (Activation)        (None, 7, 7, 1848)   0           conv5_16_x1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_16_x1 (Conv2D)            (None, 7, 7, 128)    236544      relu5_16_x1[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2_bn (BatchNormalizat (None, 7, 7, 128)    512         conv5_16_x1[0][0]
# __________________________________________________________________________________________________
# relu5_16_x2 (Activation)        (None, 7, 7, 128)    0           conv5_16_x2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2_zeropadding (ZeroPa (None, 9, 9, 128)    0           relu5_16_x2[0][0]
# __________________________________________________________________________________________________
# conv5_16_x2 (Conv2D)            (None, 7, 7, 32)     36864       conv5_16_x2_zeropadding[0][0]
# __________________________________________________________________________________________________
# concatenate_115 (Concatenate)   (None, 7, 7, 1880)   0           concatenate_114[0][0]
#                                                                  conv5_16_x2[0][0]
# __________________________________________________________________________________________________
# conv5_blk_bn (BatchNormalizatio (None, 7, 7, 1880)   7520        concatenate_115[0][0]
# __________________________________________________________________________________________________
# relu5_blk (Activation)          (None, 7, 7, 1880)   0           conv5_blk_bn[0][0]
# __________________________________________________________________________________________________
# pool5 (GlobalAveragePooling2D)  (None, 1880)         0           relu5_blk[0][0]
# __________________________________________________________________________________________________
# fc6 (Dense)                     (None, 1000)         1881000     pool5[0][0]
# __________________________________________________________________________________________________
# prob (Activation)               (None, 1000)         0           fc6[0][0]
# ==================================================================================================
# Total params: 13,509,904
# Trainable params: 13,378,304
# Non-trainable params: 131,600
# __________________________________________________________________________________________________

# %%
from imagenet_download.imagenet_utils import load_data

# %%
train_data,train_label,val_data,val_label = load_data()
# Out:
# /home/ecbm4040/Project/e4040-2019fall-project-purj-ud2310-rn2494-jy3012
# /home/ecbm4040/Project/e4040-2019fall-project-purj-ud2310-rn2494-jy3012/split_data/train

# %%
from matplotlib import pyplot as plt
plt.imshow(train_data[200])
plt.show()

# %%
train_label[200]
# Out:
# 'sport'
